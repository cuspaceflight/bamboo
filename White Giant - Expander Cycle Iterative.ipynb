# %% [markdown]
# # White Giant with Expander Cycle
#
# Investigation into using a turbopump at the cooling system exit

# %%
#Import required modules
import bamboo as bam
import bamboo.cooling as cool
import bamboo.materials


import numpy as np
import matplotlib.pyplot as plt
import pypropep as ppp
import bamboo.plot
from CoolProp.CoolProp import PropsSI

import matplotlib as mpl

# %% [markdown]
# ### *Engine setup*

# %%
'''Chamber conditions'''
pc = 10e5                   #Chamber pressure (Pa)
mdot = 5.4489               #Mass flow rate (kg/s)
p_amb = 1.01325e5           #Ambient pressure (Pa). 1.01325e5 is sea level atmospheric.
OF_ratio = 5                #Oxidiser/fuel mass ratio
water_mass_fraction = 0.0   #Fraction of the fuel that is water, by mass

'''Get combustion properties from pypropep'''
ppp.init()
e = ppp.Equilibrium()
ipa = ppp.PROPELLANTS['ISOPROPYL ALCOHOL']
water = ppp.PROPELLANTS['WATER']
n2o = ppp.PROPELLANTS['NITROUS OXIDE']

#Add propellants by mass fractions (note the mass fractions can add up to more than 1)
e.add_propellants_by_mass([(ipa, 1-water_mass_fraction), (water, water_mass_fraction), (n2o, OF_ratio)])

#Adiabatic combustion using chamber pressure                      
e.set_state(P = pc/1e5, type='HP')                      

gamma = e.properties.Isex   #pyrpopep uses 'Isex' for the ratio of specific heats
cp = 1000*e.properties.Cp   #Cp is given in kJ/kg/K, we want J/kg/K
Tc = e.properties.T

'''Set up the engine object'''
perfect_gas = bam.PerfectGas(gamma = gamma, cp = cp)    #Gas for frozen flow
chamber_conditions = bam.ChamberConditions(pc, Tc, mdot)
nozzle = bam.Nozzle.from_engine_components(perfect_gas, chamber_conditions, p_amb, type = "rao")
engine = bam.Engine(perfect_gas, chamber_conditions, nozzle)

print(f"\nNozzle throat area = {nozzle.At} m^2, nozzle exit area = {nozzle.Ae} m^2")

'''Check the thrust and specific impulse'''
print("")
print(f"Chamber Temperature: {Tc} K")
print(f"Gamma = {gamma}")
print(f"cp = {cp} J/kg/K")
print("")
print(f"Sea level thrust = {engine.thrust(1e5)/1000} kN      (using perfect gas relations)")
print(f"Sea level Isp = {engine.isp(1e5)} s         (using perfect gas relations)")

'''Transport properties'''
#CoolProp takes mole fractions for mixtures I believe, not mass fractions.
#Setup the exhaust gas transport properties
def Pr_gas(T, p):
    return PropsSI("PRANDTL", "T", T, "P", p, "NITROGEN")

def mu_gas(T, p):
    return PropsSI("VISCOSITY", "T", T, "P", p, "NITROGEN")

def k_gas(T, p):
    return PropsSI("CONDUCTIVITY", "T", T, "P", p, "NITROGEN")

gas_transport = bam.cooling.TransportProperties(type = "functions",
                                                Pr = Pr_gas,
                                                mu = mu_gas,
                                                k = k_gas)

#Set up the coolant transport properties
def Pr_coolant(T, p):
    try:
        return PropsSI("PRANDTL", "T", T, "P", p, "ETHANOL")
    except ValueError:
        return PropsSI("PRANDTL", "T", T, "Q", 0, "ETHANOL")

def mu_coolant(T, p):
    try:
        return PropsSI("VISCOSITY", "T", T, "P", p, "ETHANOL")
    except ValueError:
        return PropsSI("VISCOSITY", "T", T, "Q", 0, "ETHANOL")
    
def k_coolant(T, p):
    try:
        return PropsSI("CONDUCTIVITY", "T", T, "P", p, "ETHANOL")
    except ValueError:
        return PropsSI("CONDUCTIVITY", "T", T, "Q", 0, "ETHANOL")
    
def cp_coolant(T, p):
    try:
        return PropsSI("CPMASS", "T", T, "P", p, "ETHANOL")
    except ValueError:
        return PropsSI("CPMASS", "T", T, "Q", 0, "ETHANOL")
    
def rho_coolant(T, p):#
    try:
        return PropsSI("DMASS", "T", T, "P", p, "ETHANOL") 
    except ValueError:
        return PropsSI("DMASS", "T", T, "Q", 0, "ETHANOL")
    
def T_from_enthalpy(enthalpy, p):
    return PropsSI('T','H', enthalpy,'P', p, 'ETHANOL')

def enthalpy_from_T(T, p):
    return PropsSI('H','T', T, 'P', p, 'ETHANOL')

coolant_transport = bam.cooling.TransportProperties(type = "functions",
                                                    Pr = Pr_coolant,
                                                    mu = mu_coolant,
                                                    k = k_coolant,
                                                    cp = cp_coolant,
                                                    rho = rho_coolant,
                                                    T_from_enthalpy = T_from_enthalpy,
                                                    enthalpy_from_T = enthalpy_from_T)



#Add the gas transport properties to the engine
engine.add_exhaust_transport(gas_transport)

'''Chamber and wall geometry'''
Ac = np.pi*0.12**2                      #Chamber cross-sectional area (m^2)
inner_wall_thickness = 5e-3    #Placeholder whilst we generate the rest of the geometry
L_star = 1.2                           #L_star = Volume_c/Area_t
chamber_length = L_star*nozzle.At/Ac   #Length of the combustion chamber

engine.add_geometry(chamber_length = chamber_length,
                    chamber_area = Ac,
                    inner_wall_thickness = inner_wall_thickness)

'''Coolant jacket'''
mdot_coolant = mdot/(OF_ratio + 1)               #Coolant mass flow rate
inlet_T = 298.15                                 #Coolant inlet temperature (K)
inlet_p0 = float("nan")                          #Coolant inlet stagnation pressure (Pa) - placeholder for now
wall_material = bam.materials.CopperC700         #Copper inner wall

#Add the cooling jacket
engine.add_cooling_jacket(wall_material, 
                          inlet_T, 
                          inlet_p0, 
                          coolant_transport, 
                          mdot_coolant, 
                          configuration = "spiral", 
                          channel_width =  14e-3,
                          channel_height = 14e-3,
                          blockage_ratio = (1/49),
                          number_of_ribs = 2)

#Add the exhaust gas transport properties
engine.add_exhaust_transport(gas_transport)

'''Graphite insert'''
ablative_material = bam.materials.Graphite
engine.add_ablative(ablative_material)

#Plot the geometry
engine.plot_geometry()
plt.show()
# Out:
# Loaded 1921 thermo species
# Loaded 1031 propellants
# NOTE: Area ratio is outside of data range for Rao bell nozzle graphs (minimum 3.7, maximum 47). Using a 15 deg cone nozzle instead.
#
# Nozzle throat area = 0.010981538511554725 m^2, nozzle exit area = 0.025928421938621233 m^2
#
# Chamber Temperature: 3086.8481884125868 K
# Gamma = 1.1453747614753838
# cp = 4215.9009306078415 J/kg/K
#
# Sea level thrust = 13.993998041231935 kN      (using perfect gas relations)
# Sea level Isp = 261.8860079470274 s         (using perfect gas relations)

# %% [markdown]
# ## Turbopump
# Iterate until we find a compressor exit temperature that equals the coolant inlet pressure

# %%
from CoolProp.CoolProp import PhaseSI
import scipy.optimize

#Turbomachinery inputs
turbine_exit_p0 = 20e5
turbine_isentropic_efficiency = 0.7

compressor_inlet_p0 = 5e5
compressor_inlet_T0 = 298
compressor_isentropic_efficiency = 0.7

def compressor_outlet_pressure(coolant_inlet_p0, print_output = False):
    engine.add_cooling_jacket(wall_material, 
                              inlet_T, 
                              coolant_inlet_p0, 
                              coolant_transport, 
                              mdot_coolant, 
                              configuration = "spiral", 
                              channel_width =  14e-3,
                              channel_height = 14e-3,
                              blockage_ratio = (1/49),
                              number_of_ribs = 2)

    #Run simulation
    global heating_data
    
    #Run simulation with coarser discretisation so it runs faster - doesn't seem to change result too much 
    heating_data = engine.steady_heating_analysis(to_json = False, 
                                                  h_gas_model = 'bartz-sigma', 
                                                  h_coolant_model = 'dittus-boelter',
                                                  number_of_points = 200,
                                                  gas_fudge_factor = 1.3)
    
    #-----TURBINE-----
    turbine_inlet_enthalpy =  heating_data["enthalpy_coolant"][-1]
    turbine_inlet_p0 = heating_data["p0_coolant"][-1]
    turbine_inlet_entropy = PropsSI('S','H', turbine_inlet_enthalpy, 'P', turbine_inlet_p0, 'ETHANOL')

    turbine_exit_enthalpy_isen = PropsSI('H','S', turbine_inlet_entropy, 'P', turbine_exit_p0, 'ETHANOL')
    turbine_enthalpy_drop = turbine_isentropic_efficiency*(turbine_inlet_enthalpy - turbine_exit_enthalpy_isen)
    turbine_exit_enthalpy = turbine_inlet_enthalpy - turbine_enthalpy_drop
    
    #-----COMPRESSOR-----
    compressor_inlet_enthalpy = PropsSI('H','T', compressor_inlet_T0, 'P', compressor_inlet_p0, 'ETHANOL')
    compressor_inlet_entropy = PropsSI('S','T', compressor_inlet_T0, 'P', compressor_inlet_p0, 'ETHANOL')
    compressor_exit_enthalpy = compressor_inlet_enthalpy + turbine_enthalpy_drop
    compressor_exit_enthalpy_isen = compressor_inlet_enthalpy + compressor_isentropic_efficiency*turbine_enthalpy_drop

    #Find pressure from isentropic exit enthalpy
    compressor_exit_p0 = PropsSI('P','H', compressor_exit_enthalpy_isen, 'S', compressor_inlet_entropy, 'ETHANOL')
    
    if print_output:
        print("----------TURBINE----------")
        print(f"Enthalpy available = {turbine_enthalpy_drop/1e3} kJ/kg")
        print("")
        print(f"Inlet temperature = {PropsSI('T','H', turbine_inlet_enthalpy, 'P', turbine_inlet_p0, 'ETHANOL') - 273.15} C")
        print(f"Inlet pressure = {turbine_inlet_p0/1e5} bar")
        print(f"Inlet entropy = {turbine_inlet_entropy/1e3} kJ/kg/K")
        print("")
        print(f"Inlet phase = {PhaseSI('H', turbine_inlet_enthalpy, 'P', turbine_inlet_p0, 'ETHANOL')}")
        print(f"Inlet dryness fraction (molar) = {PropsSI('Q','H', turbine_inlet_enthalpy, 'P', turbine_inlet_p0, 'ETHANOL')}") 
        print("")
        print(f"Exit temperature = {PropsSI('T','H', turbine_exit_enthalpy, 'P', turbine_exit_p0, 'ETHANOL') - 273.15} C")
        print(f"Exit pressure = {turbine_exit_p0/1e5} bar")
        print(f"Exit entropy = {PropsSI('S','H', turbine_exit_enthalpy, 'P', turbine_exit_p0, 'ETHANOL')/1e3} kJ/kg/K")
        print("")
        print(f"Exit phase = {PhaseSI('H', turbine_exit_enthalpy, 'P', turbine_exit_p0, 'ETHANOL')}")
        print(f"Exit dryness fraction (molar) = {PropsSI('Q','H', turbine_exit_enthalpy, 'P', turbine_exit_p0, 'ETHANOL')}")   
        print("")
        print("")
        print("----------COMPRESSOR----------")
        print(f"Inet temperature = {compressor_inlet_T0 - 273.15} C")
        print(f"Inet pressure = {compressor_inlet_p0/1e5} bar")
        print(f"Inlet entropy = {compressor_inlet_entropy/1e3} kJ/kg/K")
        print("")
        print(f"Inlet phase = {PhaseSI('T', compressor_inlet_T0, 'P', compressor_inlet_p0, 'ETHANOL')}")
        print("")
        print(f"Exit temperature = {PropsSI('T','H', compressor_exit_enthalpy, 'P', compressor_exit_p0, 'ETHANOL') - 273.15} C")
        print(f"Exit pressure = {compressor_exit_p0/1e5} bar")
        print(f"Exit entropy = {PropsSI('S','H', compressor_exit_enthalpy, 'P', compressor_exit_p0, 'ETHANOL')/1e3} kJ/kg/K")
        print(f"")
        print(f"Exit phase = {PhaseSI('H', compressor_exit_enthalpy, 'P', compressor_exit_p0, 'ETHANOL')}")
        print(f"Exit wetness fraction = {PropsSI('Q','H', compressor_exit_enthalpy, 'P', compressor_exit_p0, 'ETHANOL')}")
    
    return compressor_exit_p0

def pressure_error(coolant_inlet_p0):
    compressor_exit_p0 = compressor_outlet_pressure(coolant_inlet_p0)
    error = compressor_exit_p0 - coolant_inlet_p0
    
    print(f"Error = {error/1e5} bar for coolant_inlet_p0 = {coolant_inlet_p0/1e5} bar")
    return error

solution = scipy.optimize.root_scalar(pressure_error, bracket=[30e5, 40e5], method='brentq', xtol = 1e-7)
print(f"\nCoolant inlet pressure solution = {solution.root/1e5} bar")
# Out:
# Error = -29.981939947849416 bar for coolant_inlet_p0 = 30.0 bar
# Error = 39.934162348142834 bar for coolant_inlet_p0 = 40.0 bar
# Error = -3.33264322337972 bar for coolant_inlet_p0 = 34.28827394023194 bar
# Error = 0.9936820675782068 bar for coolant_inlet_p0 = 34.78323990676602 bar
# Error = 0.011240264633102343 bar for coolant_inlet_p0 = 34.66955478788826 bar
# Error = -5.441174702718854e-07 bar for coolant_inlet_p0 = 34.66825847150799 bar
# Error = 8.478760719299316e-11 bar for coolant_inlet_p0 = 34.66825853425689 bar
# Error = -6.75395131111145e-11 bar for coolant_inlet_p0 = 34.668258534247116 bar
# Error = -1.2002573348581791e-08 bar for coolant_inlet_p0 = 34.66825853425145 bar
# Error = -1.1957036331295967e-08 bar for coolant_inlet_p0 = 34.668258534256374 bar
#
# Coolant inlet pressure solution = 34.66825853425689 bar

# %%
compressor_outlet_p0 = compressor_outlet_pressure(solution.root, print_output = True)
# Out:
# ----------TURBINE----------
# Enthalpy available = 5.387163001912657 kJ/kg
#
# Inlet temperature = 186.66746918613904 C
# Inlet pressure = 22.80366599594152 bar
# Inlet entropy = 2.0836073291909365 kJ/kg/K
#
# Inlet phase = twophase
# Inlet dryness fraction (molar) = 0.9266207408703916
#
# Exit temperature = 180.45219374228628 C
# Exit pressure = 20.0 bar
# Exit entropy = 2.088697216708078 kJ/kg/K
#
# Exit phase = twophase
# Exit dryness fraction (molar) = 0.9244972930780019
#
#
# ----------COMPRESSOR----------
# Inet temperature = 24.850000000000023 C
# Inet pressure = 5.0 bar
# Inlet entropy = -0.4408113251877051 kJ/kg/K
#
# Inlet phase = liquid
#
# Exit temperature = 26.013533416626387 C
# Exit pressure = 34.668258534341675 bar
# Exit entropy = -0.43540310077793604 kJ/kg/K
#
# Exit phase = liquid
# Exit wetness fraction = -1.0

# %%
#Show plots
#bam.plot.plot_temperatures(heating_data, show_gas = True, show_ablative = True)
bam.plot.plot_temperatures(heating_data, show_gas = False, show_ablative = False)
bam.plot.plot_jacket_pressure(heating_data)
bam.plot.plot_coolant_velocities(heating_data)

plt.show()

# %%
#T-S diagram for ethanol
import CoolProp
from CoolProp.Plots import PropertyPlot
plot = PropertyPlot('ETHANOL', 'TS')
plot.calc_isolines(CoolProp.iQ)
plot.calc_isolines(CoolProp.iP)
plot.show()
# Out:
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:608: UserWarning: Please use "calc_sat_range" to calculate saturation and isoquality lines. Input ranges are discarded.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 892.942954, 5661.566422 with index (243,): unable to solve 1phase PY flash with Tmin=265.131, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [260.82 J/mol/K] is above the maximum value of 260.641275157 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 892.942954, 5691.959025 with index (244,): unable to solve 1phase PY flash with Tmin=265.131, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [262.22 J/mol/K] is above the maximum value of 260.641275157 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 892.942954, 5722.351627 with index (245,): unable to solve 1phase PY flash with Tmin=265.131, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [263.62 J/mol/K] is above the maximum value of 260.641275157 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 892.942954, 5752.744230 with index (246,): unable to solve 1phase PY flash with Tmin=265.131, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [265.02 J/mol/K] is above the maximum value of 260.641275157 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 892.942954, 5783.136833 with index (247,): unable to solve 1phase PY flash with Tmin=265.131, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [266.42 J/mol/K] is above the maximum value of 260.641275157 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 892.942954, 5813.529436 with index (248,): unable to solve 1phase PY flash with Tmin=265.131, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [267.82 J/mol/K] is above the maximum value of 260.641275157 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 892.942954, 5843.922038 with index (249,): unable to solve 1phase PY flash with Tmin=265.131, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [269.22 J/mol/K] is above the maximum value of 260.641275157 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5448.818203 with index (236,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [251.019 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5479.210806 with index (237,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [252.419 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5509.603409 with index (238,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [253.819 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5539.996011 with index (239,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [255.219 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5570.388614 with index (240,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [256.619 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5600.781217 with index (241,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [258.019 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5631.173819 with index (242,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [259.419 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5661.566422 with index (243,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [260.82 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5691.959025 with index (244,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [262.22 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5722.351627 with index (245,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [263.62 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5752.744230 with index (246,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [265.02 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5783.136833 with index (247,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [266.42 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5813.529436 with index (248,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [267.82 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 2989.748681, 5843.922038 with index (249,): unable to solve 1phase PY flash with Tmin=282.369, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [269.22 J/mol/K] is above the maximum value of 250.593725225 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5236.069984 with index (229,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [241.218 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5266.462587 with index (230,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [242.618 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5296.855190 with index (231,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [244.018 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5327.247792 with index (232,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [245.418 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5357.640395 with index (233,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [246.818 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5388.032998 with index (234,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [248.218 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5418.425601 with index (235,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [249.618 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5448.818203 with index (236,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [251.019 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5479.210806 with index (237,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [252.419 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5509.603409 with index (238,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [253.819 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5539.996011 with index (239,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [255.219 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5570.388614 with index (240,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [256.619 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5600.781217 with index (241,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [258.019 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5631.173819 with index (242,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [259.419 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5661.566422 with index (243,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [260.82 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5691.959025 with index (244,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [262.22 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5722.351627 with index (245,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [263.62 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5752.744230 with index (246,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [265.02 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5783.136833 with index (247,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [266.42 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5813.529436 with index (248,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [267.82 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 10010.266772, 5843.922038 with index (249,): unable to solve 1phase PY flash with Tmin=302.363, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [269.22 J/mol/K] is above the maximum value of 240.545800126 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5023.321766 with index (222,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [231.417 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5053.714368 with index (223,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [232.817 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5084.106971 with index (224,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [234.217 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5114.499574 with index (225,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [235.617 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5144.892176 with index (226,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [237.017 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5175.284779 with index (227,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [238.417 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5205.677382 with index (228,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [239.817 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5236.069984 with index (229,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [241.218 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5266.462587 with index (230,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [242.618 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5296.855190 with index (231,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [244.018 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5327.247792 with index (232,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [245.418 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5357.640395 with index (233,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [246.818 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5388.032998 with index (234,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [248.218 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5418.425601 with index (235,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [249.618 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5448.818203 with index (236,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [251.019 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5479.210806 with index (237,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [252.419 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5509.603409 with index (238,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [253.819 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5539.996011 with index (239,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [255.219 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5570.388614 with index (240,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [256.619 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5600.781217 with index (241,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [258.019 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5631.173819 with index (242,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [259.419 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5661.566422 with index (243,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [260.82 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5691.959025 with index (244,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [262.22 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5722.351627 with index (245,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [263.62 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5752.744230 with index (246,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [265.02 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5783.136833 with index (247,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [266.42 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5813.529436 with index (248,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [267.82 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 33516.342517, 5843.922038 with index (249,): unable to solve 1phase PY flash with Tmin=325.913, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [269.22 J/mol/K] is above the maximum value of 230.496619045 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 4810.573547 with index (215,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [221.616 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 4840.966149 with index (216,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [223.016 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 4871.358752 with index (217,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [224.416 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 4901.751355 with index (218,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [225.816 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 4932.143957 with index (219,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [227.216 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 4962.536560 with index (220,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [228.616 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 4992.929163 with index (221,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [230.016 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5023.321766 with index (222,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [231.417 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5053.714368 with index (223,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [232.817 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5084.106971 with index (224,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [234.217 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5114.499574 with index (225,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [235.617 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5144.892176 with index (226,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [237.017 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5175.284779 with index (227,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [238.417 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5205.677382 with index (228,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [239.817 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5236.069984 with index (229,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [241.218 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5266.462587 with index (230,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [242.618 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5296.855190 with index (231,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [244.018 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5327.247792 with index (232,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [245.418 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5357.640395 with index (233,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [246.818 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5388.032998 with index (234,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [248.218 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5418.425601 with index (235,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [249.618 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5448.818203 with index (236,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [251.019 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5479.210806 with index (237,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [252.419 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5509.603409 with index (238,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [253.819 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5539.996011 with index (239,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [255.219 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5570.388614 with index (240,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [256.619 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5600.781217 with index (241,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [258.019 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5631.173819 with index (242,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [259.419 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5661.566422 with index (243,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [260.82 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5691.959025 with index (244,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [262.22 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5722.351627 with index (245,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [263.62 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5752.744230 with index (246,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [265.02 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5783.136833 with index (247,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [266.42 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5813.529436 with index (248,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [267.82 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 112219.308569, 5843.922038 with index (249,): unable to solve 1phase PY flash with Tmin=354.185, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [269.22 J/mol/K] is above the maximum value of 220.443234381 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4567.432725 with index (207,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [210.415 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4597.825328 with index (208,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [211.815 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4628.217931 with index (209,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [213.215 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4658.610533 with index (210,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [214.615 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4689.003136 with index (211,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [216.015 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4719.395739 with index (212,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [217.415 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4749.788341 with index (213,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [218.815 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4780.180944 with index (214,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [220.215 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4810.573547 with index (215,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [221.616 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4840.966149 with index (216,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [223.016 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4871.358752 with index (217,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [224.416 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4901.751355 with index (218,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [225.816 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4932.143957 with index (219,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [227.216 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4962.536560 with index (220,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [228.616 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 4992.929163 with index (221,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [230.016 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 5023.321766 with index (222,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [231.417 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 5053.714368 with index (223,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [232.817 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 5084.106971 with index (224,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [234.217 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 5114.499574 with index (225,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [235.617 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 375732.322500, 5144.892176 with index (226,): unable to solve 1phase PY flash with Tmin=388.969, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [237.017 J/mol/K] is above the maximum value of 210.3757937 J/mol/K
#   warnings.warn(
# ...
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4628.217931 with index (209,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [213.215 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4658.610533 with index (210,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [214.615 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4689.003136 with index (211,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [216.015 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4719.395739 with index (212,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [217.415 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4749.788341 with index (213,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [218.815 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4780.180944 with index (214,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [220.215 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4810.573547 with index (215,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [221.616 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4840.966149 with index (216,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [223.016 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4871.358752 with index (217,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [224.416 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4901.751355 with index (218,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [225.816 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4932.143957 with index (219,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [227.216 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4962.536560 with index (220,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [228.616 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 4992.929163 with index (221,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [230.016 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5023.321766 with index (222,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [231.417 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5053.714368 with index (223,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [232.817 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5084.106971 with index (224,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [234.217 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5114.499574 with index (225,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [235.617 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5144.892176 with index (226,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [237.017 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5175.284779 with index (227,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [238.417 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5205.677382 with index (228,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [239.817 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5236.069984 with index (229,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [241.218 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5266.462587 with index (230,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [242.618 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5296.855190 with index (231,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [244.018 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5327.247792 with index (232,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [245.418 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5357.640395 with index (233,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [246.818 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5388.032998 with index (234,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [248.218 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5418.425601 with index (235,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [249.618 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5448.818203 with index (236,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [251.019 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5479.210806 with index (237,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [252.419 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5509.603409 with index (238,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [253.819 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5539.996011 with index (239,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [255.219 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5570.388614 with index (240,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [256.619 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5600.781217 with index (241,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [258.019 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5631.173819 with index (242,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [259.419 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5661.566422 with index (243,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [260.82 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5691.959025 with index (244,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [262.22 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5722.351627 with index (245,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [263.62 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5752.744230 with index (246,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [265.02 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5783.136833 with index (247,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [266.42 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5813.529436 with index (248,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [267.82 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Common.py:655: UserWarning: An error occurred for inputs 14102998.590178, 5843.922038 with index (249,): unable to solve 1phase PY flash with Tmin=160.284, Tmax=975 due to error: HSU_P_flash_singlephase_Brent could not find a solution because Smolar [269.22 J/mol/K] is above the maximum value of 179.196481887 J/mol/K
#   warnings.warn(
# D:\anaconda3\lib\site-packages\CoolProp\Plots\Plots.py:217: UserWarning: Detected an incomplete phase envelope, fixing it numerically.
#   warnings.warn("Detected an incomplete phase envelope, fixing it numerically.")
